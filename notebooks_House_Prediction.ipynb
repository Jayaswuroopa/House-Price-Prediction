# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("Book1.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.xlabel('area (sqr ft)')
plt.ylabel('price (US$)')
plt.scatter(df.area, df.price)

plt.plot(df.area, reg.predict(df[['area']]), color="blue")

plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# c:\Users\JAYASWUROOPA\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
d=pd.read_csv("Book11.csv")
d
# Out:
#     area
# 0   1000
# 1   2000
# 2   3000
# 3   4000
# 4   5000
# 5   6000
# 6   7000
# 7   8000
# 8   9000
# 9   1500
# 10  2500
# 11  3500
# 12  4500
# 13  5500
# 14  6500
# 15  7600
# 16  8900

# %%
p=reg.predict(d)
p
# Out:
# array([ 316404.10958904,  452191.78082192,  587979.45205479,
#         723767.12328767,  859554.79452055,  995342.46575342,
#        1131130.1369863 , 1266917.80821918, 1402705.47945205,
#         384297.94520548,  520085.61643836,  655873.28767123,
#         791660.95890411,  927448.63013699, 1063236.30136986,
#        1212602.73972603, 1389126.71232877])

# %%
d['prices']=p
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   2000  4.521918e+05
# 2   3000  5.879795e+05
# 3   4000  7.237671e+05
# 4   5000  8.595548e+05
# 5   6000  9.953425e+05
# 6   7000  1.131130e+06
# 7   8000  1.266918e+06
# 8   9000  1.402705e+06
# 9   1500  3.842979e+05
# 10  2500  5.200856e+05
# 11  3500  6.558733e+05
# 12  4500  7.916610e+05
# 13  5500  9.274486e+05
# 14  6500  1.063236e+06
# 15  7600  1.212603e+06
# 16  8900  1.389127e+06

# %%
import pickle

pickle.dump(reg, open("model.pkl","wb"))
